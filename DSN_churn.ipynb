# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_data = pd.read_csv("TRAIN (1).csv")

# %%
train_data.describe()
# Out:
#        network_age  Customer tenure in month  \
# count  1400.000000               1400.000000
# mean   1450.634286                 48.354479
# std    1276.008188                 42.533536
# min      -5.000000                 -0.170000
# 25%     287.000000                  9.567500
# 50%    1171.000000                 39.030000
# 75%    2242.000000                 74.732500
# max    5451.000000                181.700000
#
#        Total Spend in Months 1 and 2 of 2017  Total SMS Spend  \
# count                            1400.000000      1400.000000
# mean                              805.641729        30.394286
# std                              1251.742068        60.885095
# min                                 4.910000         0.000000
# 25%                               155.537500         2.620000
# 50%                               606.575000        13.715000
# 75%                              1018.395500        31.205000
# ...

# %%
train_data
# Out:
#      Customer ID  network_age  Customer tenure in month  \
# 0        ADF0039        123.0                      4.10
# 1        ADF0041       1316.0                     43.87
# 2        ADF0051       2385.0                     79.50
# 3        ADF0059       1614.0                     53.80
# 4        ADF0060       2175.0                     72.50
# 5        ADF0066        158.0                      5.27
# 6        ADF0068        110.0                      3.67
# 7        ADF0072        558.0                     18.60
# 8        ADF0079        115.0                      3.83
# 9        ADF0085       1868.0                     62.27
# 10       ADF0091       1196.0                     39.87
# 11       ADF0092        174.0                      5.80
# 12       ADF0094        122.0                      4.07
# 13       ADF0095        441.0                     14.70
# 14       ADF0105       2132.0                     71.07
# 15       ADF0108        180.0                      6.00
# ...

# %%
train_data.shape
# Out:
# (1401, 16)

# %%
col_names = train_data.columns.tolist()
col_names
# Out:
# ['Customer ID',
#  'network_age',
#  'Customer tenure in month',
#  'Total Spend in Months 1 and 2 of 2017',
#  'Total SMS Spend',
#  'Total Data Spend',
#  'Total Data Consumption',
#  'Total Unique Calls',
#  'Total Onnet spend ',
#  'Total Offnet spend',
#  'Total Call centre complaint calls',
#  'Network type subscription in Month 1',
#  'Network type subscription in Month 2',
#  'Most Loved Competitor network in in Month 1',
#  'Most Loved Competitor network in in Month 2',
#  'Churn Status']

# %%
#to select the datatypes that are float
train_data.select_dtypes(include=['float64'])
# Out:
#       network_age  Customer tenure in month  \
# 0           123.0                      4.10
# 1          1316.0                     43.87
# 2          2385.0                     79.50
# 3          1614.0                     53.80
# 4          2175.0                     72.50
# 5           158.0                      5.27
# 6           110.0                      3.67
# 7           558.0                     18.60
# 8           115.0                      3.83
# 9          1868.0                     62.27
# 10         1196.0                     39.87
# 11          174.0                      5.80
# 12          122.0                      4.07
# 13          441.0                     14.70
# 14         2132.0                     71.07
# 15          180.0                      6.00
# 16          114.0                      3.80
# 17         3496.0                    116.53
# 18          422.0                     14.07
# 19         1914.0                     63.80
# ...

# %%
object_data = train_data.select_dtypes(include=['O'])
object_data.head()
# Out:
#   Customer ID Network type subscription in Month 1  \
# 0     ADF0039                                   2G
# 1     ADF0041                                   2G
# 2     ADF0051                                   2G
# 3     ADF0059                                   2G
# 4     ADF0060                                   2G
#
#   Network type subscription in Month 2  \
# 0                                   2G
# 1                                   2G
# 2                                   2G
# 3                                   2G
# 4                                   3G
#
#   Most Loved Competitor network in in Month 1  \
# 0                                        Uxaa
# 1                                        Uxaa
# 2                                    Weematel
# 3                                           0
# 4                                    Weematel
#
#   Most Loved Competitor network in in Month 2
# 0                                       Mango
# ...

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1401 entries, 0 to 1400
# Data columns (total 16 columns):
# Customer ID                                    1400 non-null object
# network_age                                    1400 non-null float64
# Customer tenure in month                       1400 non-null float64
# Total Spend in Months 1 and 2 of 2017          1400 non-null float64
# Total SMS Spend                                1400 non-null float64
# Total Data Spend                               1400 non-null float64
# Total Data Consumption                         1400 non-null float64
# Total Unique Calls                             1400 non-null float64
# Total Onnet spend                              1400 non-null float64
# Total Offnet spend                             1400 non-null float64
# Total Call centre complaint calls              1400 non-null float64
# Network type subscription in Month 1           1225 non-null object
# ...

# %% [markdown]
# # Data cleaning

# %% [markdown]
# Check how messy the data is using seaborn

# %%
plt.figure(figsize = (12,10))
sns.heatmap(train_data.isnull(), yticklabels = False, cbar = False, cmap = 'viridis')

# %% [markdown]
# ## Fill up the missing data

# %%
train_data["Network type subscription in Month 1"].value_counts()
# Out:
# 3G       636
# 2G       304
# Other    285
# Name: Network type subscription in Month 1, dtype: int64

# %%
train_data["Network type subscription in Month 1"] = train_data["Network type subscription in Month 1"].fillna('2G')

# %%
train_data["Network type subscription in Month 2"].value_counts()
# Out:
# 3G       687
# Other    285
# 2G       284
# Name: Network type subscription in Month 2, dtype: int64

# %%
train_data["Network type subscription in Month 2"] = train_data["Network type subscription in Month 2"].fillna('3G')

# %%
Missing_Values = train_data[train_data.isnull().any(axis=1)].head()
Missing_Values
# Out:
#      Customer ID  network_age  Customer tenure in month  \
# 303      ADF2000       2308.0                     76.93
# 1400         NaN          NaN                       NaN
#
#       Total Spend in Months 1 and 2 of 2017  Total SMS Spend  \
# 303                                   481.9              0.0
# 1400                                    NaN              NaN
#
#       Total Data Spend  Total Data Consumption  Total Unique Calls  \
# 303              125.0             620515.1875                 3.0
# 1400               NaN                     NaN                 NaN
#
#       Total Onnet spend   Total Offnet spend  \
# 303                  0.0               609.0
# 1400                 NaN                 NaN
#
#       Total Call centre complaint calls Network type subscription in Month 1  \
# 303                                 1.0                                   2G
# 1400                                NaN                                   2G
#
# ...

# %% [markdown]
# # Change the object features to float

# %%
train_data.drop(train_data.index[-1], inplace = True)

# %%
train_data[1395:]
# Out:
#      Customer ID  network_age  Customer tenure in month  \
# 1395     ADF1956        136.0                      4.53
# 1396     ADF1965       1795.0                     59.83
# 1397     ADF1967        203.0                      6.77
# 1398     ADF1971        109.0                      3.63
# 1399     ADF1982        904.0                     30.13
#
#       Total Spend in Months 1 and 2 of 2017  Total SMS Spend  \
# 1395                               270.3344             6.58
# 1396                              1024.8460           111.99
# 1397                              1143.4972            19.84
# 1398                                45.0900             0.00
# 1399                               161.1300             0.00
#
#       Total Data Spend  Total Data Consumption  Total Unique Calls  \
# 1395              2.50               7410.7529                62.0
# 1396             10.00             493671.9863               149.0
# ...

# %%
#train_net = train_data.groupby('Network type subscription in Month 1').describe()
#train_net

# %%
train_data.dtypes
# Out:
# Customer ID                                     object
# network_age                                    float64
# Customer tenure in month                       float64
# Total Spend in Months 1 and 2 of 2017          float64
# Total SMS Spend                                float64
# Total Data Spend                               float64
# Total Data Consumption                         float64
# Total Unique Calls                             float64
# Total Onnet spend                              float64
# Total Offnet spend                             float64
# Total Call centre complaint calls              float64
# Network type subscription in Month 1            object
# Network type subscription in Month 2            object
# Most Loved Competitor network in in Month 1     object
# Most Loved Competitor network in in Month 2     object
# Churn Status                                   float64
# dtype: object

# %%
train_data.isnull().any()
# Out:
# Customer ID                                    False
# network_age                                    False
# Customer tenure in month                       False
# Total Spend in Months 1 and 2 of 2017          False
# Total SMS Spend                                False
# Total Data Spend                               False
# Total Data Consumption                         False
# Total Unique Calls                             False
# Total Onnet spend                              False
# Total Offnet spend                             False
# Total Call centre complaint calls              False
# Network type subscription in Month 1           False
# Network type subscription in Month 2           False
# Most Loved Competitor network in in Month 1     True
# Most Loved Competitor network in in Month 2     True
# Churn Status                                   False
# dtype: bool

# %%
train_data.isnull().any()
# Out:
# Customer ID                                    False
# network_age                                    False
# Customer tenure in month                       False
# Total Spend in Months 1 and 2 of 2017          False
# Total SMS Spend                                False
# Total Data Spend                               False
# Total Data Consumption                         False
# Total Unique Calls                             False
# Total Onnet spend                              False
# Total Offnet spend                             False
# Total Call centre complaint calls              False
# Network type subscription in Month 1           False
# Network type subscription in Month 2           False
# Most Loved Competitor network in in Month 1     True
# Most Loved Competitor network in in Month 2     True
# Churn Status                                   False
# dtype: bool

# %%
train_data["Most Loved Competitor network in in Month 1"].value_counts()
# Out:
# PQza        340
# Uxaa        324
# Mango       204
# ToCall      202
# Zintel      152
# Weematel    139
# 0            38
# Name: Most Loved Competitor network in in Month 1, dtype: int64

# %%
train_data["Most Loved Competitor network in in Month 2"].value_counts()
# Out:
# Uxaa        829
# PQza        308
# Mango       101
# ToCall       64
# Weematel     51
# Zintel       46
# Name: Most Loved Competitor network in in Month 2, dtype: int64

# %%
train_data['Total SMS Spend'].hist()

# %%
sns.pairplot(train_data, palette = 'rainbow', size = 4)

# %%
train_data['Total Data Spend'].hist(bins= 30)

# %%
train_data = train_data.drop(["Customer ID", "network_age"], axis = 1)

# %% [markdown]
# # one hot encoding

# %%
#train_data['Network type subscription in Month 1_new'] = train_data['Network type subscription in Month 1']

# %%
#train_data['Network type subscription in Month 1_new'].value_counts()

# %%
train1 = pd.get_dummies(train_data, columns = train_data['Network type subscription in Month 1'], drop_first = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-345-8a29358d588f> in <module>()
# ----> 1 train1 = pd.get_dummies(train_data, columns = train_data['Network type subscription in Month 1'], drop_first = True)
#
# c:\users\abayomi\appdata\local\programs\python\python35\lib\site-packages\pandas\core\reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first)
#    1091             with_dummies = []
#    1092         else:
# -> 1093             with_dummies = [data.drop(columns_to_encode, axis=1)]
#    1094
#    1095         for (col, pre, sep) in zip(columns_to_encode, prefix, prefix_sep):
#
# c:\users\abayomi\appdata\local\programs\python\python35\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, level, inplace, errors)
#    1905                 new_axis = axis.drop(labels, level=level, errors=errors)
# ...

# %%
train1 = pd.get_dummies(train_data, columns = train_data['Network type subscription in Month 2'], drop_first = True)

# %%
#ecoded_values = {"Network type subscription in Month 1_new":{"2G": 0, "3G":1, "Other":2}}

# %%
train1 = pd.get_dummies(train_data, columns = train_data['Most Loved Competitor network in in Month 1'], drop_first = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-346-14b922e4837b> in <module>()
# ----> 1 train1 = pd.get_dummies(train_data, columns = train_data['Most Loved Competitor network in in Month 1'], drop_first = True)
#
# c:\users\abayomi\appdata\local\programs\python\python35\lib\site-packages\pandas\core\reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first)
#    1091             with_dummies = []
#    1092         else:
# -> 1093             with_dummies = [data.drop(columns_to_encode, axis=1)]
#    1094
#    1095         for (col, pre, sep) in zip(columns_to_encode, prefix, prefix_sep):
#
# c:\users\abayomi\appdata\local\programs\python\python35\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, level, inplace, errors)
#    1905                 new_axis = axis.drop(labels, level=level, errors=errors)
# ...

# %%
#train_data.replace(Recoded_values, inplace = True)

# %%
train1 = pd.get_dummies(train_data, columns = train_data['Most Loved Competitor network in in Month 2'], drop_first = True)

# %%
#train_data[['Network type subscription in Month 1', 'Network type subscription in Month 1_new']].tail()

# %%
#train_data['Network type subscription in Month 1_new'].dtype

# %%
#for month 2
#train_data['Network type subscription in Month 2_new'] = train_data['Network type subscription in Month 2']

# %%
#train_data['Network type subscription in Month 2_new'].value_counts()

# %%
#Recoded_values_2 = {"Network type subscription in Month 2_new":{"2G": 0, "3G":1, "Other":2}}

# %%
#train_data.replace(Recoded_values_2, inplace = True)

# %%
#train_data[['Network type subscription in Month 2', 'Network type subscription in Month 2_new']].tail()

# %%
train_data.tail()

# %%
train_data.isnull().any()

# %%
train_data['Most Loved Competitor network in in Month 1'].value_counts()

# %%
train_data['Most Loved Competitor network in in Month 2'].value_counts()

# %%
#train_data["Most Loved Competitor network in in Month 2"] = train_data["Most Loved Competitor network in in Month 2"].fillna('Uxaa', inplace = True)

# %%
#train_data["Most Loved Competitor network in in Month 1"] = train_data["Most Loved Competitor network in in Month 1"].fillna('PQza', inplace = True)

# %%
#train_data["Most Loved Competitor network in in Month 1_new"] = train_data["Most Loved Competitor network in in Month 1"]

# %%
#train_data["Most Loved Competitor network in in Month 1_new"].value_counts()

# %%
#encode = {"Most Loved Competitor network in in Month 1_new":{"Uxaa": 1, "PQza":2, "Mango":3, "ToCall": 4, "Weematel": 5, "Zintel": 6}}

# %%
train_data.replace(encode, inplace = True)

# %%
#train_data[["Most Loved Competitor network in in Month 1", "Most Loved Competitor network in in Month 1_new"]].tail()

# %%
#train_data["Most Loved Competitor network in in Month 2_new"] = train_data["Most Loved Competitor network in in Month 2"]

# %%
#train_data["Most Loved Competitor network in in Month 2_new"].value_counts()

# %%
#encode_2 = {"Most Loved Competitor network in in Month 2_new":{"Uxaa": 0, "PQza":1, "Mango":2, "ToCall": 3, "Weematel": 4, "Zintel": 5}}

# %%
#train_data.replace(encode_2, inplace = True)

# %%
#train_data["Most Loved Competitor network in in Month 2_new"].astype(np.float64)

# %%
#train_data[["Most Loved Competitor network in in Month 2", "Most Loved Competitor network in in Month 2_new"]].tail()

# %%
#train_data.head()

# %%
#new_train = train_data.drop(["Network type subscription in Month 1", "Network type subscription in Month 2",
                             #"Most Loved Competitor network in in Month 1","Most Loved Competitor network in in Month 2"], 
                            #axis = 1)
#new_train.head()

# %% [markdown]
# # feature engineering

# %%
train_data.dtypes

# %%
train1 = train1.drop(["Most Loved Competitor network in in Month 1",
                            "Most Loved Competitor network in in Month 2"], axis = 1)

# %%
train1.head()

# %%
#train_new = train_data.drop(["Network type subscription in Month 1", "Network type subscription in Month 2"], axis = 1)

# %%
#train_new.head()

# %%
#train_new["Most Loved Competitor network in in Month 1_new"] = train_new["Most Loved Competitor network in in Month 1_new"].fillna('0').astype(np.float64, inplace = True)

# %%
train1.dtypes

# %%
#train_new["Most Loved Competitor network in in Month 2_new"] = train_new["Most Loved Competitor network in in Month 2_new"].fillna('0').astype(np.float64, inplace = True)

# %%
corr_matrix = train1.corr()
f, ax = plt.subplots(figsize=(18, 10))
sns.heatmap(corr_matrix, linewidths=2.0, ax=ax, annot=True)
ax.set_title('Correlation Matrix')

# %%
train1['competitor'] = train1["Most Loved Competitor network in in Month 1_new"] + train_new["Most Loved Competitor network in in Month 2_new"]

# %%
train1["total spend"] = train1["Total Data Spend"] + train1["Total SMS Spend"] + train1["Total Offnet spend"]

# %%
train1["comp"] = train1["Total Call centre complaint calls"]* train1["competitor"]

# %%
train1.head()

# %%
train = train1.drop(["Total SMS Spend", "Total Data Spend", "Total Spend in Months 1 and 2 of 2017" ], axis = 1)

# %%
train1.isnull().any()

# %%
train.head()

# %% [markdown]
# # Build a model right away

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error 
from sklearn.metrics import classification_report

# %%
X = train.drop('Churn Status',axis=1)
y = train['Churn Status']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=101)

# %% [markdown]
# ## Decision tree model

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)

# %%
predictions = dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,predictions))

# %%
print(confusion_matrix(y_test,predictions))

# %% [markdown]
# ## Using Random classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=400)

# %%
rfc.fit(X_train,y_train)

# %%
predictions = rfc.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,predictions))

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[114  40]
#  [ 40  86]]

# %% [markdown]
# # Test with test data

# %%
test = pd.read_csv("TEST (2).csv")

# %%
test.head()
# Out:
#   Customer ID  network_age  Customer tenure in month  \
# 0     ADF0001         1012                 33.733333
# 1     ADF0002          137                  4.566667
# 2     ADF0003          202                  6.733333
# 3     ADF0004          165                  5.500000
# 4     ADF0005          759                 25.300000
#
#    Total Spend in Months 1 and 2 of 2017  Total SMS Spend  Total Data Spend  \
# 0                              1560.1156            14.04             226.3
# 1                              1705.8368            73.63               5.0
# 2                              1720.3008             4.36             245.0
# 3                              1732.2800             0.00              12.5
# 4                              1873.0600            69.57             412.5
#
#    Total Data Consumption  Total Unique Calls  Total Onnet spend   \
# 0            3.126093e+06                  64               14503
# ...

# %%
test.isnull().any()
# Out:
# Customer ID                                    False
# network_age                                    False
# Customer tenure in month                       False
# Total Spend in Months 1 and 2 of 2017          False
# Total SMS Spend                                False
# Total Data Spend                               False
# Total Data Consumption                         False
# Total Unique Calls                             False
# Total Onnet spend                              False
# Total Offnet spend                             False
# Total Call centre complaint calls              False
# Network type subscription in Month 1            True
# Network type subscription in Month 2            True
# Most Loved Competitor network in in Month 1    False
# Most Loved Competitor network in in Month 2    False
# dtype: bool

# %%
#test["Network type subscription in Month 1"] = test["Network type subscription in Month 1"].fillna("2G", inplace = True)

# %%
#test["Network type subscription in Month 2"] = test["Network type subscription in Month 2"].fillna("3G", inplace = True)

# %%
test.head()
# Out:
#   Customer ID  network_age  Customer tenure in month  \
# 0     ADF0001         1012                 33.733333
# 1     ADF0002          137                  4.566667
# 2     ADF0003          202                  6.733333
# 3     ADF0004          165                  5.500000
# 4     ADF0005          759                 25.300000
#
#    Total Spend in Months 1 and 2 of 2017  Total SMS Spend  Total Data Spend  \
# 0                              1560.1156            14.04             226.3
# 1                              1705.8368            73.63               5.0
# 2                              1720.3008             4.36             245.0
# 3                              1732.2800             0.00              12.5
# 4                              1873.0600            69.57             412.5
#
#    Total Data Consumption  Total Unique Calls  Total Onnet spend   \
# 0            3.126093e+06                  64               14503
# ...

# %%
test.isnull().any()
# Out:
# Customer ID                                    False
# network_age                                    False
# Customer tenure in month                       False
# Total Spend in Months 1 and 2 of 2017          False
# Total SMS Spend                                False
# Total Data Spend                               False
# Total Data Consumption                         False
# Total Unique Calls                             False
# Total Onnet spend                              False
# Total Offnet spend                             False
# Total Call centre complaint calls              False
# Network type subscription in Month 1            True
# Network type subscription in Month 2            True
# Most Loved Competitor network in in Month 1    False
# Most Loved Competitor network in in Month 2    False
# dtype: bool

# %%
test.dtypes
# Out:
# Customer ID                                     object
# network_age                                      int64
# Customer tenure in month                       float64
# Total Spend in Months 1 and 2 of 2017          float64
# Total SMS Spend                                float64
# Total Data Spend                               float64
# Total Data Consumption                         float64
# Total Unique Calls                               int64
# Total Onnet spend                                int64
# Total Offnet spend                               int64
# Total Call centre complaint calls                int64
# Network type subscription in Month 1            object
# Network type subscription in Month 2            object
# Most Loved Competitor network in in Month 1     object
# Most Loved Competitor network in in Month 2     object
# dtype: object

# %%
test_again = test.drop(["Customer ID", "network_age"], axis = 1)

# %%
test_again["Most Loved Competitor network in in Month 2"].value_counts()
# Out:
# Uxaa        383
# PQza        115
# Mango        37
# Zintel       24
# Weematel     23
# ToCall       18
# Name: Most Loved Competitor network in in Month 2, dtype: int64

# %%
values = {"Most Loved Competitor network in in Month 1": {"0": 0, "Uxaa": 1, "PQza":2, "Mango":3, "ToCall": 4, "Weematel": 5, "Zintel": 6},
         "Most Loved Competitor network in in Month 2": {"Uxaa": 1, "PQza":2, "Mango":3, "ToCall": 4, "Weematel": 5, "Zintel": 6}}
test_again.replace(values, inplace = True)

# %%
test_again.head()
# Out:
#    Customer tenure in month  Total Spend in Months 1 and 2 of 2017  \
# 0                 33.733333                              1560.1156
# 1                  4.566667                              1705.8368
# 2                  6.733333                              1720.3008
# 3                  5.500000                              1732.2800
# 4                 25.300000                              1873.0600
#
#    Total SMS Spend  Total Data Spend  Total Data Consumption  \
# 0            14.04             226.3            3.126093e+06
# 1            73.63               5.0            1.628809e+02
# 2             4.36             245.0            3.334607e+06
# 3             0.00              12.5            6.682924e+05
# 4            69.57             412.5            6.666975e+06
#
#    Total Unique Calls  Total Onnet spend   Total Offnet spend  \
# 0                  64               14503               12402
# 1                 515               29832               88953
# ...

# %%
test_again['Network type subscription in Month 1_new'] = test['Network type subscription in Month 1']

# %%
test_again['Network type subscription in Month 1_new'].value_counts()
# Out:
# 3G       338
# 2G       103
# Other     89
# Name: Network type subscription in Month 1_new, dtype: int64

# %%
Recoded_1 = {"Network type subscription in Month 1_new":{"2G": 0, "3G":1, "Other":2}}

# %%
test_again.replace(Recoded_1, inplace = True)

# %%
test_again['Network type subscription in Month 2_new'] = test['Network type subscription in Month 2']

# %%
test_again['Network type subscription in Month 2_new'].value_counts()
# Out:
# 3G       351
# 2G        98
# Other     89
# Name: Network type subscription in Month 2_new, dtype: int64

# %%
Recoded_2 = {"Network type subscription in Month 2_new":{"2G": 0, "3G":1, "Other":2}}

# %%
test_again.replace(Recoded_2, inplace = True)

# %%
test_again.head()
# Out:
#    Customer tenure in month  Total Spend in Months 1 and 2 of 2017  \
# 0                 33.733333                              1560.1156
# 1                  4.566667                              1705.8368
# 2                  6.733333                              1720.3008
# 3                  5.500000                              1732.2800
# 4                 25.300000                              1873.0600
#
#    Total SMS Spend  Total Data Spend  Total Data Consumption  \
# 0            14.04             226.3            3.126093e+06
# 1            73.63               5.0            1.628809e+02
# 2             4.36             245.0            3.334607e+06
# 3             0.00              12.5            6.682924e+05
# 4            69.57             412.5            6.666975e+06
#
#    Total Unique Calls  Total Onnet spend   Total Offnet spend  \
# 0                  64               14503               12402
# 1                 515               29832               88953
# ...

# %%
test_again = test_again.drop(["Network type subscription in Month 1", "Network type subscription in Month 2"], axis = 1)

# %%
test_again.isnull().any()
# Out:
# Customer tenure in month                       False
# Total Spend in Months 1 and 2 of 2017          False
# Total SMS Spend                                False
# Total Data Spend                               False
# Total Data Consumption                         False
# Total Unique Calls                             False
# Total Onnet spend                              False
# Total Offnet spend                             False
# Total Call centre complaint calls              False
# Most Loved Competitor network in in Month 1    False
# Most Loved Competitor network in in Month 2    False
# Network type subscription in Month 1_new        True
# Network type subscription in Month 2_new        True
# dtype: bool

# %%
test_again.dtypes
# Out:
# Customer tenure in month                       float64
# Total Spend in Months 1 and 2 of 2017          float64
# Total SMS Spend                                float64
# Total Data Spend                               float64
# Total Data Consumption                         float64
# Total Unique Calls                               int64
# Total Onnet spend                                int64
# Total Offnet spend                               int64
# Total Call centre complaint calls                int64
# Most Loved Competitor network in in Month 1      int64
# Most Loved Competitor network in in Month 2      int64
# Network type subscription in Month 1_new       float64
# Network type subscription in Month 2_new       float64
# dtype: object

# %%
test_again["Network type subscription in Month 1_new"] = test_again["Network type subscription in Month 1_new"].fillna("0").astype(np.float64, inplace = True)

# %%
test_again["Network type subscription in Month 2_new"] = test_again["Network type subscription in Month 2_new"].fillna("1").astype(np.float64, inplace = True)

# %%
test_again['competitor'] = test_again["Most Loved Competitor network in in Month 1"] + test_again["Most Loved Competitor network in in Month 2"]

# %%
test_again["total spend"] = test_again["Total Data Spend"] + test_again["Total SMS Spend"] + test_again["Total Offnet spend"]

# %%
test_again["comp"] = test_again["Total Call centre complaint calls"] * test_again["competitor"]

# %%
test_again.head()
# Out:
#    Customer tenure in month  Total Spend in Months 1 and 2 of 2017  \
# 0                 33.733333                              1560.1156
# 1                  4.566667                              1705.8368
# 2                  6.733333                              1720.3008
# 3                  5.500000                              1732.2800
# 4                 25.300000                              1873.0600
#
#    Total SMS Spend  Total Data Spend  Total Data Consumption  \
# 0            14.04             226.3            3.126093e+06
# 1            73.63               5.0            1.628809e+02
# 2             4.36             245.0            3.334607e+06
# 3             0.00              12.5            6.682924e+05
# 4            69.57             412.5            6.666975e+06
#
#    Total Unique Calls  Total Onnet spend   Total Offnet spend  \
# 0                  64               14503               12402
# 1                 515               29832               88953
# ...

# %%
test.head()
# Out:
#   Customer ID  network_age  Customer tenure in month  \
# 0     ADF0001         1012                 33.733333
# 1     ADF0002          137                  4.566667
# 2     ADF0003          202                  6.733333
# 3     ADF0004          165                  5.500000
# 4     ADF0005          759                 25.300000
#
#    Total Spend in Months 1 and 2 of 2017  Total SMS Spend  Total Data Spend  \
# 0                              1560.1156            14.04             226.3
# 1                              1705.8368            73.63               5.0
# 2                              1720.3008             4.36             245.0
# 3                              1732.2800             0.00              12.5
# 4                              1873.0600            69.57             412.5
#
#    Total Data Consumption  Total Unique Calls  Total Onnet spend   \
# 0            3.126093e+06                  64               14503
# ...

# %%
test_new = test_again.drop(["Total SMS Spend", "Total Data Spend", "Total Spend in Months 1 and 2 of 2017"], axis = 1)

# %%
pred = rfc.predict(test_new)

# %%
result = pd.DataFrame(pred)

# %%
result['Customer ID'] = test["Customer ID"]

# %%
result.dtypes
# Out:
# 0              float64
# Customer ID     object
# dtype: object

# %%
result.columns = ["Churn Status", "Customer ID"]

# %%
result.head()
# Out:
#    Churn Status Customer ID
# 0           0.0     ADF0001
# 1           1.0     ADF0002
# 2           1.0     ADF0003
# 3           1.0     ADF0004
# 4           0.0     ADF0005

# %%
result = result.reindex_axis(["Customer ID", "Churn Status"], axis = 1)

# %%
result.head()
# Out:
#   Customer ID  Churn Status
# 0     ADF0001           0.0
# 1     ADF0002           1.0
# 2     ADF0003           1.0
# 3     ADF0004           1.0
# 4     ADF0005           0.0

# %%
result.to_csv('DSN_churn2', index = False)
